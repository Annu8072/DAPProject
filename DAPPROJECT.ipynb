# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_csv(r"C:\Users\HP\Downloads\Fifa_world_cup_matches.csv")
data.head()
# Out:
#            team1         team2 possession team1 possession team2  \
# 0          QATAR       ECUADOR              42%              50%
# 1        ENGLAND          IRAN              72%              19%
# 2        SENEGAL   NETHERLANDS              44%              45%
# 3  UNITED STATES         WALES              51%              39%
# 4      ARGENTINA  SAUDI ARABIA              64%              24%
#
#   possession in contest  number of goals team1  number of goals team2  \
# 0                    8%                      0                      2
# 1                    9%                      6                      2
# 2                   11%                      0                      2
# 3                   10%                      1                      1
# 4                   12%                      1                      2
#
#           date     hour category  ...  penalties scored team1  \
# 0  20 NOV 2022  17 : 00  Group A  ...                       0
# ...

# %%
data.tail()
# Out:
#         team1    team2 possession team1 possession team2  \
# 59    ENGLAND   FRANCE              54%              36%
# 60  ARGENTINA  CROATIA              34%              54%
# 61     FRANCE  MOROCCO              34%              55%
# 62    CROATIA  MOROCCO              45%              45%
# 63  ARGENTINA   FRANCE              46%              40%
#
#    possession in contest  number of goals team1  number of goals team2  \
# 59                   10%                      1                      2
# 60                   12%                      3                      0
# 61                   11%                      2                      0
# 62                   10%                      2                      1
# 63                   14%                      3                      3
#
#            date     hour                  category  ...  \
# 59  10 DEC 2022  20 : 00             Quarter-final  ...
# 60  13 DEC 2022  20 : 00                Semi-final  ...
# ...

# %%
data.columns
# Out:
# Index(['team1', 'team2', 'possession team1', 'possession team2',
#        'possession in contest', 'number of goals team1',
#        'number of goals team2', 'date', 'hour', 'category',
#        'total attempts team1', 'total attempts team2', 'conceded team1',
#        'conceded team2', 'goal inside the penalty area team1',
#        'goal inside the penalty area team2',
#        'goal outside the penalty area team1',
#        'goal outside the penalty area team2', 'assists team1', 'assists team2',
#        'on target attempts team1', 'on target attempts team2',
#        'off target attempts team1', 'off target attempts team2',
#        'attempts inside the penalty area team1',
#        'attempts inside the penalty area  team2',
#        'attempts outside the penalty area  team1',
#        'attempts outside the penalty area  team2', 'left channel team1',
#        'left channel team2', 'left inside channel team1',
#        'left inside channel team2', 'central channel team1',
# ...

# %%
data.isnull().sum()
# Out:
# team1                                0
# team2                                0
# possession team1                     0
# possession team2                     0
# possession in contest                0
#                                     ..
# own goals team2                      0
# forced turnovers team1               0
# forced turnovers team2               0
# defensive pressures applied team1    0
# defensive pressures applied team2    0
# Length: 88, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 88 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   team1                                                  64 non-null     object
#  1   team2                                                  64 non-null     object
#  2   possession team1                                       64 non-null     object
#  3   possession team2                                       64 non-null     object
#  4   possession in contest                                  64 non-null     object
#  5   number of goals team1                                  64 non-null     int64
#  6   number of goals team2                                  64 non-null     int64
#  7   date                                                   64 non-null     object
# ...

# %%
data = {
    'team': ['team1', 'team2'],
    'total_attempts': [35, 28], 
}
df = pd.DataFrame(data)

# Create the bar plot
sns.barplot(x='team', y='total_attempts', data=df, palette="viridis")

# Add title and labels
plt.title('Total Attempts by Team')
plt.xlabel('Teams')
plt.ylabel('Total Attempts')

# Show the plot
plt.show()

# %%
data = {
    'Metric': ['Total Attempts', 'Passes', 'Goals Scored', 'Corners'],
    'Team1': [35, 420, 3, 8],  # Replace with values for team1
    'Team2': [28, 390, 2, 6],  # Replace with values for team2
}

df = pd.DataFrame(data)
df_melted = df.melt(id_vars='Metric', var_name='Team', value_name='Value')
sns.barplot(x='Metric', y='Value', hue='Team', data=df_melted, palette='viridis')
plt.title('Comparison of Metrics Between Team1 and Team2')
plt.xlabel('Metrics')
plt.ylabel('Values')
plt.xticks(rotation=30)
plt.show()

# %%
data = {
    'Team': ['Team1', 'Team2'],
    'Passes': [420, 390],  # Replace these with actual values
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Create the pie chart
plt.figure(figsize=(6, 6))
plt.pie(
    df['Passes'], 
    labels=df['Team'], 
    autopct='%1.1f%%',  # Show percentages
    startangle=90,  # Align start angle
    colors=['#FFD700', '#FF4500'],  # Custom colors
    explode=(0.05, 0),  # Slightly separate Team1
    shadow=True  # Add shadow for aesthetics
)

# Add a title
plt.title('Passes Comparison Between Team1 and Team2')

# Show the plot
plt.show()

# %%
data = {
    'total_attempts_team1': [5, 8, 7, 10, 15, 12, 11, 14, 9, 6],
    'total_attempts_team2': [6, 9, 8, 11, 13, 15, 10, 12, 8, 7]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Create a histogram for total_attempts_team1
plt.figure(figsize=(8, 6))
sns.histplot(df['total_attempts_team1'], bins=8, kde=True, color='blue', label='Team1 Attempts')

# Add title and labels
plt.title('Distribution of Total Attempts for Team1')
plt.xlabel('Total Attempts')
plt.ylabel('Frequency')
plt.legend()

# Show the plot
plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Create a histogram comparing total attempts for both teams
plt.figure(figsize=(8, 6))
sns.histplot(df['total_attempts_team1'], bins=8, kde=True, color='blue', label='Team1 Attempts', alpha=0.6)
sns.histplot(df['total_attempts_team2'], bins=8, kde=True, color='orange', label='Team2 Attempts', alpha=0.6)

# Add title and labels
plt.title('Comparison of Total Attempts for Team1 and Team2')
plt.xlabel('Total Attempts')
plt.ylabel('Frequency')
plt.legend()

# Show the plot
plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
